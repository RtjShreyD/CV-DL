# %% [markdown]
# <a href="https://colab.research.google.com/github/RtjShreyD/CV-DL/blob/master/Colors_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the necessary packages
import numpy as np
import imutils
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("pokemon_games.png")
image = cv2.resize(image, (200, 200))

# %%
# define the list of boundaries
boundaries = [
	([17, 15, 100], [50, 56, 200]),
	([86, 31, 4], [220, 88, 50]),
	([25, 146, 190], [62, 174, 250]),
	([103, 86, 65], [145, 133, 128])
]

# loop over the boundaries
for (lower, upper) in boundaries:
	# create NumPy arrays from the boundaries
	lower = np.array(lower, dtype = "uint8")
	upper = np.array(upper, dtype = "uint8")
 
	# find the colors within the specified boundaries and apply
	# the mask
	mask = cv2.inRange(image, lower, upper)
	output = cv2.bitwise_and(image, image, mask = mask)
 
	# show the images
	cv2_imshow(np.hstack([image, output]))
	cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F7C808D0CC0>
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F7C808D0D68>
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F7C808D0FD0>
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F7C808D0CC0>
